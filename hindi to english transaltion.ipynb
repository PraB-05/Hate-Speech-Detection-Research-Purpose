# %%
import pandas as pd
pd.set_option('display.max_Colwidth',None)

# %%
df = pd.read_csv("hindi_dataset.tsv" ,sep="\t",
    engine="python",
    quoting=3,
    on_bad_lines="skip")

# %%
df.head()
# Out:
#          text_id  \
# 0  hasoc_hi_5556
# 1  hasoc_hi_5648
# 2   hasoc_hi_164
# 3  hasoc_hi_3530
# 4  hasoc_hi_5206
#
#                                                                                                                                                                                                                                                                                           text  \
# 0                                                                                                                                                                                                                           बांग्लादेश की शानदार वापसी, भारत को 314 रन पर रोका #INDvBAN #CWC19
# 1                                                                                                                                                                                              सब रंडी नाच देखने मे व्यस्त जैसे ही कोई #शांतीदूत के साथ कुछ होगा सब #रंडीरोना शुरू कर देंगे
# ...

# %%
df['Label_binary'] = df['task_1'].map({'HOF':1,'NOT':0})

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4665 entries, 0 to 4664
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   text_id       4665 non-null   object
#  1   text          4665 non-null   object
#  2   task_1        4665 non-null   object
#  3   task_2        4665 non-null   object
#  4   task_3        4665 non-null   object
#  5   Label_binary  4665 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 218.8+ KB

# %%
df = df[['text' , 'Label_binary']]

# %%
df.head()
# the dataset is ready for the translation purpose and ease for better understanding
# Out:
#                                                                                                                                                                                                                                                                                           text  \
# 0                                                                                                                                                                                                                           बांग्लादेश की शानदार वापसी, भारत को 314 रन पर रोका #INDvBAN #CWC19
# 1                                                                                                                                                                                              सब रंडी नाच देखने मे व्यस्त जैसे ही कोई #शांतीदूत के साथ कुछ होगा सब #रंडीरोना शुरू कर देंगे
# ...

# %% [markdown]
# ###### df['Label_binary'].value_counts()

# %%
# !pip install deep_translator

# %%
from deep_translator import GoogleTranslator
import time

# %%
# print(f"Starting translation for {len(df)} rows...")

# translator = GoogleTranslator(source='auto', target='en')
# translated_texts = []  # Changed to plural

# for index, text in enumerate(df['text']):
#     text_str = str(text)
    
#     try:
#         # Fixed typo: changed tramlator to translator
#         english_text = translator.translate(text_str)
#         translated_texts.append(english_text)  # Changed to plural
#     except Exception as e:
#         print(f"Error at row {index}: {e}")
#         translated_texts.append("")  # Changed to plural
        
#     if index % 100 == 0 and index > 0:
#         print(f"Translated {index} rows out of {len(df)}...")
        
#     # Sleep for half a second to avoid Error 429 (Too Many Requests)
#     time.sleep(0.5)

# # 4. Add the translated text as a new column
# df['translated_text'] = translated_texts  # Changed to plural

# # 5. SAVE IT! So you never have to wait 40 minutes again!
# df.to_csv("translated_hindi_dataset.csv", index=False)
print("Done! Saved as 'translated_hindi_dataset.csv'.")
# Out:
# Starting translation for 4665 rows...
# Translated 100 rows out of 4665...
# Error at row 109: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Translated 200 rows out of 4665...
# Translated 300 rows out of 4665...
# Translated 400 rows out of 4665...
# Translated 500 rows out of 4665...
# Translated 600 rows out of 4665...
# Translated 700 rows out of 4665...
# Translated 800 rows out of 4665...
# Error at row 856: ("Connection broken: ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None)", ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))
# Translated 900 rows out of 4665...
# Translated 1000 rows out of 4665...
# Translated 1100 rows out of 4665...
# ...

# %%
df_translated = pd.read_csv('translated_hindi_dataset.csv')

# %%
df_translated.sample(10)
# Out:
#                                                                                                                                                                                                                                                                                              text  \
# 4657                                                                                                          BJP भी जानती है कि यह हरामी बदशकल बहुत ही महाचूतिया, सुअर से भी गिरा इंसान है, बुरा ना मानो कीचड़ से लथपथ इस जानवर का @ManojTiwariMP @DocVatsa @AamAadmiParty @ravi4354 @JanLokPaal
# 1055                                                                                                                  इस हरामी को चौराहे पर उल्टा लटका कर मारो।  कानून तो सत्ता के हाथ की रखैल बन चूका तभी मुजरिमों की हिम्मत बढ़ गई है।  वरना एसे पागल कुत्तों को चैराहे पर गोली मार देनी चाहये।
# ...

# %%
df_translated.isnull().sum()
# Out:
# text                0
# Label_binary        0
# translated_text    10
# dtype: int64

# %%
df_translated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4655 entries, 0 to 4664
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   text             4655 non-null   object
#  1   Label_binary     4655 non-null   int64
#  2   translated_text  4655 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 145.5+ KB

# %%
df_translated.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_translated = df_translated.dropna()

# %%
df_translated.isnull().sum()
# Out:
# text               0
# Label_binary       0
# translated_text    0
# dtype: int64

# %% [markdown]
# # Clean up begun..

# %%
"Unnamed : 0" in df.columns
# Out:
# False

# %%
print("See the distribution of 0's and 1's:\n",df_translated['Label_binary'].value_counts())
# Out:
# See the distribution of 0's and 1's:
#  Label_binary
# 1    2465
# 0    2190
# Name: count, dtype: int64
