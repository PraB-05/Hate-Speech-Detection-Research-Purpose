# %%
import pandas as pd
pd.set_option('display.max_Colwidth',None)

# %%
df = pd.read_csv('translated_hindi_dataset.csv')

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                           text  \
# 0                                                                                                                                                                                                                           बांग्लादेश की शानदार वापसी, भारत को 314 रन पर रोका #INDvBAN #CWC19
# 1                                                                                                                                                                                              सब रंडी नाच देखने मे व्यस्त जैसे ही कोई #शांतीदूत के साथ कुछ होगा सब #रंडीरोना शुरू कर देंगे
# 2  तुम जैसे हरामियों के लिए बस जूतों की कमी है शुक्र कर अभी तुम्हारी लिंचिंग हुई नहीं है हिंदुओं के जागने की देर है सच में होगी अभी तो तुम जैसे हरामी सुवर ड्रामा बनाएं हो   सुवर कहीं का मौलाना।   तुम जैसे हरामियों कुत्ते की मौत मारना चाहिए सुवर जैसी शक्ल  रंडी की औलाद सुवर कहीं का ।।।।
# 3                                          बीजेपी MLA आकाश विजयवर्गीय जेल से रिहा, जमानत मिलने की खुशी में एक समर्थक ने इंदौर में हर्ष फायरिंग की  #AkashVijayvargiya   https://abpnews.abplive.in/india-news/celebratory-firing-outside-bjp-mla-akash-vijayvargiya-office-in-indore-1157241 …
# 4                            चमकी बुखार: विधानसभा परिसर में आरजेडी का प्रदर्शन, तेजस्वी यादव नदारद     #biharencephalitisdeaths   https://abpnews.abplive.in/bihar-news/aes-deaths-rjd-protest-in-vidhan-sabha-campus-but-tejashwi-yadav-was-not-present-1158748 … (रिपोर्ट- @kumarprakash4u )
#
#    Label_binary  \
# 0             0
# 1             1
# 2             1
# 3             0
# 4             0
#
#                                                                                                                                                                                                                                                                                                                                            translated_text
# 0                                                                                                                                                                                                                                                                               Great comeback by Bangladesh, restricted India to 314 runs #INDvBAN #CWC19
# 1                                                                                                                                                                                                                          All the whores are busy watching the dance. As soon as something happens with a #peacemaker, all the #whores will start crying.
# 2  There is just shortage of shoes for bastards like you. Thank God you have not been lynched yet. It is too late for the Hindus to wake up. It will actually happen now. Bastards like you have created a pig drama, some Maulana of a pig.   Bastards like you, the dog should be killed, the pig-like face, the son of a whore, the pig from somewhere.
# 3                                                                                                BJP MLA Akash Vijayvargiya released from jail, in celebration of getting bail, a supporter opened fire in Indore #AkashVijayvargiya https://abpnews.abplive.in/india-news/celebratory-firing-outside-bjp-mla-akash-vijayvargiya-office-in-indore-1157241…
# 4                                                                                            Chamki fever: RJD's protest in the assembly campus, Tejashwi Yadav missing #biharencephalitisdeaths https://abpnews.abplive.in/bihar-news/aes-deaths-rjd-protest-in-vidhan-sabha-campus-but-tejashwi-yadav-was-not-present-1158748… (Report- @kumarprakash4u)

# %%
# Cleanup / preprocessing
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4665 entries, 0 to 4664
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   text             4665 non-null   object
#  1   Label_binary     4665 non-null   int64
#  2   translated_text  4655 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 109.5+ KB

# %%
df.isnull().sum()
# Out:
# text                0
# Label_binary        0
# translated_text    10
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.dropna(subset = 'translated_text')

# %%
df.isnull().sum()
# Out:
# text               0
# Label_binary       0
# translated_text    0
# dtype: int64

# %%
df['Label_binary'].value_counts()
# Out:
# Label_binary
# 1    2465
# 0    2190
# Name: count, dtype: int64

# %%
 "Unnamed : 0" in df.columns
# Out:
# False

# %%
df['text_length'] = df['translated_text'].astype(str).apply(len)
df['text_length'].describe()
# Out:
# count    4655.000000
# mean      168.645542
# std        91.939942
# min         6.000000
# 25%        93.000000
# 50%       151.000000
# 75%       238.000000
# max       719.000000
# Name: text_length, dtype: float64

# %%
# explain here the .describe() analysis

# %% [markdown]
# ## Lowercasing

# %%
df['translated_text'] = df['translated_text'].str.lower()

# %% [markdown]
# Here we will check about the presence of tags or url in the dataset

# %%
df[df['translated_text'].str.contains(r'https?://\S+|www\.\S+|@\w+|#\w+|<[^>]+>', na = False)].shape
# Out:
# (2027, 4)

# %%
df['clean_text'] = df['translated_text'].str.replace(r'https?://\S+|www\.\S+|@\w+', '', regex=True)
df['clean_text'] = df['clean_text'].str.replace(r'#', '', regex=True)

# %%
df.sample(100 , random_state = 42)
# Out:
#                                                                                                                                                                                                                                                                                      text  \
# 3307                                   महिलाओं के खिलाफ अपराध पर रोकथाम के लिए विशेष कदम उठाने की मांग। सुप्रीम कोर्ट ने ऐसे मामलों पर प्रभावी कार्रवाई के लिए देश के हर जिले में  निवारण केंद्र बनाने का सुझाव दिया। केंद्र और याचिकाकर्ता से कहा - इस पर विचार कर अपनी तरफ से सुझाव दें
# 2699                                                लगता है #गांजे को लेकर आपका निशाना #राहुल_गाँधी की तरफ है,  वैसे @AamAadmiParty को गली के #कुत्ते की तरह दर_दर नही भटकना चाहिए,  किसी एक #मालिक को चुन लो और उसीकी #सेवा में लग जाओ,  दर_दर भटकने से ना #रोटी मिलती है और ना ही #बोटी
# 3423  200 इस्लामिक आतंकवादियों ने मंदिर पर हमला किया मुर्तियो को तोड़ा , हरामियों आपसी झगड़े में  मंदीर पर हमला क्यो किया,फिर केस कमजोर करने के लिए एक नाबालिग को आगे कर दिया,अब सुवर शांति का नाटक कर रहे हैं,हरामी पतलकार एक मस्जिद तोड़ा गया होता तो तु और तेरी बेगम नंगी नाच रही होती
# 23                            बस एक सवाल का जवाब चाहिए कि जिस चिटफंड घोटाले में जांच के आदेश 2014 में आए उसमें पूछताछ/कार्रवाई 2019 में क्यों शुरू हो रही है? इसी सवाल में सब छुपा है। कौन सही कौन गलत पहचान लीजिए।  @LambaAlka @AbbasAliRushdi @SanjayAzadSln    Follow करो  @mirza__786
# 1175                                                                                                                                                                               आज दिल्ली यमुना विहार में वोटिंग किया भगवान जी का आशीर्वाद ले कर..  देश के नाम..     #DelhiModiKeSaath
# ...                                                                                                                                                                                                                                                                                   ...
# 586                                                                       दो कौड़ी के दलाल दलाली करनी है शौक से कर हुकूमत का लेकिन अगर जाट मजहब के ऊपर कुछ बोलेगा तो म****** इतना जूता पड़ेगा तुम्हारी मां का च** कि तुम्हारा बाप मोदी भी नहीं बचा पाएगा बड़वा हरामि तुम्हारी मां का च**
# 3346                                                                                                                                                                           बेगुसराय से देश द्रोही #कन्हैया_कुमार की हार ओर भोपाल से हिंदू सेरनी #प्रज्ञा_ठाकुर की जित की हार्दिक बधाई
# 2229                                                                                                                                                           sala aur karo randibaazi. make dhoni president of BCCI. only he can save country now  Dhoni to bcci- ओए भोसडीके इधर देख ले
# 4592                                                                                                                                                                                                                      मादरचोद तू खुद गवार है अगर ग्वार न होता तो आरछण ही क्यों लेता..
# 3720                                                                                                                                                                                                                   मोदी ने बजट पेश किया कि   भो श्री वाले ने  चुनावी जुमला फेक गया
#
#       Label_binary  \
# 3307             0
# 2699             0
# 3423             1
# 23               0
# 1175             0
# ...            ...
# 586              1
# 3346             1
# 2229             1
# 4592             1
# 3720             0
#
#                                                                                                                                                                                                                                                                                                               translated_text
# 3307                                     Demand to take special steps to prevent crimes against women. The Supreme Court suggested setting up redressal centers in every district of the country for effective action on such cases. Told the Center and the petitioner to consider this and give suggestions from your side.
# 2699                                               It seems that your target regarding #Ganja is towards #Rahul_Gandhi, however, @AamAadmiParty should not wander from door to door like a #dog on the street, choose one #owner and get engaged in his #service, wandering from door to door gives neither #bread nor #food.
# 3423  200 Islamic terrorists attacked the temple, broke the idols, why did the scoundrels attack the temple in a mutual feud, then to weaken the case they put forward a minor, now the pigs are pretending to be peaceful, scoundrels, if a mosque had been demolished then you and your wife would have been dancing naked.
# 23                 Just one question needs to be answered that why the inquiry/action in the chit fund scam in which investigation was ordered in 2014 is being started in 2019? Everything is hidden in this question. Identify who is right and who is wrong.  @LambaAlka @AbbasAliRushdi @SanjayAzadSln Follow @mirza__786
# 1175                                                                                                                                                                                                            Voting today in Yamuna Vihar, Delhi, taking blessings of God.. in the name of the country.. #DelhiModiKeSaath
# ...                                                                                                                                                                                                                                                                                                                       ...
# 586                                                                            Brokers of two pennies have to do the brokerage of tax government with hobby, but if Jat says anything on religion, then your mother's shoe will be so bad that even your father Modi will not be able to save your mother's f**, you bastard.
# 3346                                                                                                                                                                                    Hearty congratulations to the defeat of traitor #Kanhaiya_Kumar from Begusarai and victory of Hindu queen #Pragya_Thakur from Bhopal.
# 2229                                                                                                                                                                                                sala aur karo randibaazi. make Dhoni president of BCCI. only he can save country now Dhoni to bcci- Oye fucking look here
# 4592                                                                                                                                                                                                                 Motherfucker, you yourself are a coward. If you were not a coward then why would you have taken shelter?
# 3720                                                                                                                                                                                                                                                        When Modi presented the budget, Mr. Wale made an election slogan.
#
# [100 rows x 3 columns]

# %%
# Puntuation handeling 

import string

print(string.punctuation)
exclude = string.punctuation

def punctuation_remove(text):
    return text.translate(str.maketrans('','',exclude))

df['clean_text'] = df['clean_text'].apply(punctuation_remove)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
# There were some hindi words in it so i have replaced those with spaces 

df['clean_text'] = df['clean_text'].str.replace(r'[^a-zA-Z\s]', ' ', regex=True)

# %% [markdown]
# ## Check for Emojis

# %%
df[df["clean_text"].str.contains(r"[\U00010000-\U0010ffff]" , na = False)].shape
# No emoji is found
# Out:
# (0, 5)

# %% [markdown]
# ## Stop Words

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

stopwords = set(ENGLISH_STOP_WORDS)
stopwords.discard('no')
stopwords.discard('not')
stopwords.discard('never')
stopwords.discard('nor')

def remove_stopwords(text):
    return " ".join([word for word in text.split() if word  not in stopwords])

df['clean_text'] = df['clean_text'].apply(remove_stopwords)

# %% [markdown]
# ## Lemmatizer

# %%
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
lemmatizer = WordNetLemmatizer()

def lemmatize_text(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])

df["Content_lemma"] = df["clean_text"].apply(lemmatize_text)

# %% [markdown]
# df.sample(10,random_state = 42)

# %% [markdown]
# ## Model Trianing begin........

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
# splitting of the data
x = df['Content_lemma']
# x = df['Content_lemma']
y = df['Label_binary']
x_train,x_test,y_train,y_test = train_test_split(
    x,y ,test_size = 0.2 , random_state = 42
)

# %%
# vectorisation by  Tf-idf with n-gram

tfidf = TfidfVectorizer(
    ngram_range = (1,3),
    max_features = 15000,
    min_df = 3,
    max_df = 0.85
)

x_train_tfidf = tfidf.fit_transform(x_train)
x_test_tfidf = tfidf.transform(x_test)

# %%
model = LogisticRegression(max_iter = 1000)
 
model.fit(x_train_tfidf , y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(x_test_tfidf)
print("Classification report for logistic regression is :\n",classification_report(y_test , y_pred))
# Out:
# Classification report for logistic regression is :
#                precision    recall  f1-score   support
#
#            0       0.78      0.79      0.79       437
#            1       0.81      0.81      0.81       494
#
#     accuracy                           0.80       931
#    macro avg       0.80      0.80      0.80       931
# weighted avg       0.80      0.80      0.80       931

# %%
# INPUT PIPELINE

from deep_translator import GoogleTranslator
translator = GoogleTranslator(source = 'auto', target = 'en')
test_statements = [
    "कुत्ते की तरह भौंकना बंद कर, तेरी कोई औकात नहीं है।",
    "इस गद्दार को देश से निकाल देना चाहिए, यह देशद्रोही है।",
    "तुम ल��ग एकदम गवार और जाहिल हो, तुमको अकल नहीं है।",
    "शर्म कर बे, तुम जैसों को तो चौराहे पर पीटना चाहिए।",
    "बकवास बंद कर बेवकूफ, तेरा दिमाग सड़ गया है।",
    "तुम जैसे बेवकूफों को तो जेल में डाल देना चाहिए।",
    "आज मौसम बहुत अच्छा है, चलो कहीं घूमने चलते हैं।",
    "तू एक नंबर का झूठा और नीच इंसान है।",
    "भाई, क्या तुम मुझे कल की मीटिंग का समय बता सकते हो?",
    "मैं किसी से नफरत नहीं करता, सब मेरे दोस्त हैं।",
    "इन गद्दारों को देश से मार भगाओ।",
    "तुम बहुत काले हो"
]
test_state = []
for text in test_statements:
    english = translator.translate(text)
    test_state.append(english)
inputs = tfidf.transform(test_state)
model.predict(inputs)
# Out:
# array([1, 1, 1, 1, 1, 1, 0, 1, 0, 0, 0, 1, 1])
